# %% [markdown]
# # UMAP Usage

# %%
# !python --version
# Out:
# Python 3.9.4

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import umap
# %matplotlib inline
sns.set(style='white', rc={'figure.figsize':(12,8)})

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
genes=np.load("genes_qnorm_v11_clean_noutliers_nosecret.npy",allow_pickle=True)
samples=np.load("samples_qnorm_v11_clean_noutliers_nosecret.npy",allow_pickle=True)
X=np.load("results_qnorm_v11_clean_noutliers_nosecret.npy",allow_pickle=True)
results=pd.DataFrame(X,index=genes,columns=samples)

# %%
results=pd.DataFrame(X,index=genes,columns=samples).T
results.head()
# Out:
#             A1CF  A3GALT2  A4GALT  A4GNT  AAAS  AACS  AADAC  AADACL3  AADACL4  \
# GSM741172      0        0      23      0    39    15      0        0        0
# GSM741170      0        0      23      0    38    15      0        0        0
# GSM741171      0        0      23      0    37    14      0        0        0
# GSM907015      0        0       1      1    21     5      0        0        0
# GSM1193921     0        0       8      0    17     9      0        0        0
#
#             AADAT  ...  ZWILCH  ZWINT  ZXDA  ZXDB  ZXDC  ZYG11A  ZYG11B  ZYX  \
# GSM741172       4  ...      33    118     0     1     5       4       3  205
# GSM741170       6  ...      44    185     0     1     5       4       4  128
# GSM741171       5  ...      30    110     0     1     3       4       3  225
# GSM907015       0  ...       8      3     1     2     9       0       6  266
# GSM1193921      4  ...      27    221     0     2     5       2       5   97
#
#             ZZEF1  ZZZ3
# GSM741172      14    22
# GSM741170      11    28
# GSM741171      11    17
# GSM907015      18     9
# GSM1193921     10    24
#
# [5 rows x 18952 columns]

# %%
results.shape
# Out:
# (62571, 18952)

# %%
secretome=pd.read_csv("secretome_included_V11.csv",header=None,names=["gene"])

# %%
secretome.head()
# Out:
#        gene
# 0  SERPINB5
# 1   IGHV6-1
# 2      CGB3
# 3     WNT7A
# 4   DEFB126

# %%
secretome.shape
# Out:
# (1890, 1)

# %%
for gene in secretome.gene:
    if gene not in results.columns:
        print(gene)

# %%
results.drop(secretome.gene, axis=1,inplace=True)

# %%
results.head()
# Out:
#             A1CF  A3GALT2  A4GALT  A4GNT  AAAS  AACS  AADAC  AADACL3  AADACL4  \
# GSM741172      0        0      23      0    39    15      0        0        0
# GSM741170      0        0      23      0    38    15      0        0        0
# GSM741171      0        0      23      0    37    14      0        0        0
# GSM907015      0        0       1      1    21     5      0        0        0
# GSM1193921     0        0       8      0    17     9      0        0        0
#
#             AADAT  ...  ZWILCH  ZWINT  ZXDA  ZXDB  ZXDC  ZYG11A  ZYG11B  ZYX  \
# GSM741172       4  ...      33    118     0     1     5       4       3  205
# GSM741170       6  ...      44    185     0     1     5       4       4  128
# GSM741171       5  ...      30    110     0     1     3       4       3  225
# GSM907015       0  ...       8      3     1     2     9       0       6  266
# GSM1193921      4  ...      27    221     0     2     5       2       5   97
#
#             ZZEF1  ZZZ3
# GSM741172      14    22
# GSM741170      11    28
# GSM741171      11    17
# GSM907015      18     9
# GSM1193921     10    24
#
# [5 rows x 18952 columns]

# %%
results.shape
# Out:
# (62571, 18952)

# %%
hp=pd.read_csv("high_producers_v11_20_TPM.csv",usecols=[0])
lp=pd.read_csv("low_producers_v11_20_TPM.csv",usecols=[0])
hp.columns=["sample"]
lp.columns=["sample"]

# %%
hp["type"]="High_producer"
lp["type"]="Low_producer"

# %%
ctype=pd.concat([hp,lp])

# %%
ctype.shape
# Out:
# (25028, 2)

# %%
ctype.set_index("sample",inplace=True)

# %%
ctype.head()
# Out:
#                      type
# sample
# GSM3350577  High_producer
# GSM2197433  High_producer
# GSM3350601  High_producer
# GSM2197432  High_producer
# GSM3350618  High_producer

# %%
#this will discard all samples other than the chosen high and low producers
results2=pd.merge(left=results,right=ctype,left_index=True,right_index=True,how="left")

# %%
results2.head()
# Out:
#             A1CF  A3GALT2  A4GALT  A4GNT  AAAS  AACS  AADAC  AADACL3  AADACL4  \
# GSM741172      0        0      23      0    39    15      0        0        0
# GSM741170      0        0      23      0    38    15      0        0        0
# GSM741171      0        0      23      0    37    14      0        0        0
# GSM907015      0        0       1      1    21     5      0        0        0
# GSM1193921     0        0       8      0    17     9      0        0        0
#
#             AADAT  ...  ZWINT  ZXDA  ZXDB  ZXDC  ZYG11A  ZYG11B  ZYX  ZZEF1  \
# GSM741172       4  ...    118     0     1     5       4       3  205     14
# GSM741170       6  ...    185     0     1     5       4       4  128     11
# GSM741171       5  ...    110     0     1     3       4       3  225     11
# GSM907015       0  ...      3     1     2     9       0       6  266     18
# GSM1193921      4  ...    221     0     2     5       2       5   97     10
#
#             ZZZ3           type
# GSM741172     22            NaN
# GSM741170     28            NaN
# GSM741171     17            NaN
# GSM907015      9  High_producer
# GSM1193921    24            NaN
#
# [5 rows x 18953 columns]

# %%
results2.shape
# Out:
# (62571, 18953)

# %%
results2.dropna(inplace=True)

# %%
results2.shape
# Out:
# (25028, 18953)

# %%
results2.head()
# Out:
#             A1CF  A3GALT2  A4GALT  A4GNT  AAAS  AACS  AADAC  AADACL3  AADACL4  \
# GSM907015      0        0       1      1    21     5      0        0        0
# GSM1216828     8        0       0      0    22    28      1        0        0
# GSM1216812     4        0       2      0    26    27      6        0        0
# GSM1159902     0        0       0      0    84   195      0        0        0
# GSM1241140     0        0       0      0    35     9      3        0        0
#
#             AADAT  ...  ZWINT  ZXDA  ZXDB  ZXDC  ZYG11A  ZYG11B  ZYX  ZZEF1  \
# GSM907015       0  ...      3     1     2     9       0       6  266     18
# GSM1216828      3  ...      2     1     4     9       0      10   15     16
# GSM1216812      2  ...      5     0     2     9       0       8   40     11
# GSM1159902      3  ...      0     0     0     8       3       3   13     19
# GSM1241140      8  ...     93     0     3     3       0       6    3      0
#
#             ZZZ3           type
# GSM907015      9  High_producer
# GSM1216828    39  High_producer
# GSM1216812    19  High_producer
# GSM1159902    98   Low_producer
# GSM1241140    39   Low_producer
#
# [5 rows x 18953 columns]

# %%
results2.iloc[:,:-1].values
# Out:
# array([[  0,   0,   1, ..., 266,  18,   9],
#        [  8,   0,   0, ...,  15,  16,  39],
#        [  4,   0,   2, ...,  40,  11,  19],
#        ...,
#        [  0,   0,   4, ...,  67,   1,  39],
#        [  0,   0,   3, ...,  61,   1,  37],
#        [  0,   0,   0, ..., 639,  19,   9]])

# %%
results2["type"].values
# Out:
# array(['High_producer', 'High_producer', 'High_producer', ...,
#        'Low_producer', 'Low_producer', 'High_producer'], dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# %%
X = results2.iloc[:,:-1].values
y = results2["type"]

#X=RobustScaler().fit_transform(X)
#X=MinMaxScaler(feature_range=(0,1)).fit_transform(X)
#X=StandardScaler().fit_transform(X)

# %%
fit = umap.UMAP(n_neighbors=100,min_dist=1)
# %time u = fit.fit_transform(X)
# Out:
# CPU times: user 2h 53min 13s, sys: 17.5 s, total: 2h 53min 31s
# Wall time: 5min 17s

# %%
principalDf = pd.DataFrame(data = u
             , columns = ['UMAP 1-D', 'UMAP 2-D'],index=results2.index)

# %%
finalDf = pd.concat([principalDf, results2['type']],axis=1)

# %%
finalDf.head()
# Out:
#              UMAP 1-D  UMAP 2-D           type
# GSM907015   14.265511  8.382958  High_producer
# GSM1216828   5.810128  6.294680  High_producer
# GSM1216812   1.682976 -3.294926  High_producer
# GSM1159902   1.341975  3.220382   Low_producer
# GSM1241140   8.378561 -5.743002   Low_producer

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('UMAP 1-D', fontsize = 15)
ax.set_ylabel('UMAP 2-D', fontsize = 15)
ax.set_title('2D UMAP', fontsize = 20)
targets = ['High_producer', 'Low_producer']
colors = ['r', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['type'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'UMAP 1-D']
               , finalDf.loc[indicesToKeep, 'UMAP 2-D']
               , c = color
               , s = 50,alpha=0.4)
ax.legend(targets)
ax.grid()
plt.tight_layout()
ax.figure.savefig("UMAP_40_qnorm_nos.png",bbo_inches="tight")
# Out:
# <ipython-input-151-5d09f1c84e94>:17: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbo_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
#   ax.figure.savefig("UMAP_40_qnorm_nos.png",bbo_inches="tight")

# %%
plasma=pd.read_csv("plasma_cell.csv",usecols=[0])
hek=pd.read_csv("HEK293.csv",usecols=[0])
alpha=pd.read_csv("alpha_cell.csv",usecols=[0])
thymocyte=pd.read_csv("thymocyte.csv",usecols=[0])
pancreatic=pd.read_csv("pancreatic.csv",usecols=[0])

# %%
for sample in plasma.values:
    if sample in finalDf.index.values:
        finalDf.loc[sample,"type"]="Plasma Cell"

# %%
for sample in hek.values:
    if sample in finalDf.index.values:
        finalDf.loc[sample,"type"]="HEK293"

# %%
for sample in pancreatic.values:
    if sample in finalDf.index.values:
        finalDf.loc[sample,"type"]="Pancreatic Islet"

# %%
for sample in thymocyte.values:
    if sample in finalDf.index.values:
        finalDf.loc[sample,"type"]="Thymocyte"

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('UMAP 1-D', fontsize = 15)
ax.set_ylabel('UMAP 2-D', fontsize = 15)
ax.set_title('2D UMAP', fontsize = 20)
targets = ['High_producer', 'Low_producer','Plasma Cell','Pancreatic Islet','HEK293','Thymocyte']
colors = ['r', 'b','g','y','grey','k',]
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['type'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'UMAP 1-D']
               , finalDf.loc[indicesToKeep, 'UMAP 2-D']
               , c = color
               , s = 50,alpha=0.4)
ax.legend(targets)
ax.grid()
plt.tight_layout()
ax.figure.savefig("UMAP_40_tpm_color_nos.png",bbo_inches="tight")
# Out:
# <ipython-input-157-d8c0f20680ea>:17: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbo_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
#   ax.figure.savefig("UMAP_40_tpm_color_nos.png",bbo_inches="tight")
